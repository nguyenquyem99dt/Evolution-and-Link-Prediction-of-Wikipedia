# %% [markdown]
# # New part

# %% [markdown]
# ## Download data

# %%
from google.colab import drive
drive.mount('/content/GDrive')
# Out:
# Mounted at /content/GDrive

# %%
# %%bash
# cp /content/GDrive/MyDrive/WikiLinksGraph/enwiki.wikilink_graph.2002-03-01.csv.gz /content/
# gzip -d /content/enwiki.wikilink_graph.2002-03-01.csv.gz
# cp /content/GDrive/MyDrive/WikiLinksGraph/enwiki.wikilink_graph.2003-03-01.csv.gz /content/
# gzip -d /content/enwiki.wikilink_graph.2003-03-01.csv.gz

# %% [markdown]
# ## Code for model

# %%
import pandas as pd
import numpy as np
import networkx as nx
from collections import defaultdict
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score

# %%
def create_negative(g, possitives, from_pos = 10000):
  print(f'total negative: {from_pos}')
  negatives = []
  pos2neg = np.random.choice(possitives, from_pos, replace = False)
  nodes = set(g.nodes())
  i = 1
  for e1, _ in pos2neg:
    print(f'Create Negative {i}/{from_pos}|')
    i += 1
    neighs = set(nx.neighbors(g, e1))
    indicates =list(nodes - neighs)
    e2 = np.random.choice(indicates, 1)[0]
    negatives.append((e1, e2))
  negatives = list(set(negatives))
  ret = np.empty(len(negatives), dtype = object)
  ret[:] = negatives
  return ret

# %%
def create_train_dataset(g, neg_rate = 1.0):
  nodes = np.array(g.nodes())
  edges = list(g.edges())
  possitives = np.empty(len(edges), dtype = object)
  possitives[:] = edges

  from_pos = int(len(edges)*neg_rate)

  negatives = create_negative(g, possitives, from_pos)
  return possitives, negatives

# %%
def create_test_dataset(g_curr, g_aft):
  nodes_curr = set(g_curr.nodes())
  egdes_curr = set(g_curr.edges())
  edges_aft = set(g_aft.edges())
  new_edges = edges_aft - egdes_curr
  test = []
  for new_edge in new_edges:
    if (new_edge[0] in nodes_curr) and (new_edge[1] in nodes_curr):
      test.append(new_edge)
  ret = np.empty(len(test), dtype = object)
  ret[:] = test
  return ret

# %%
df1 = pd.read_csv('enwiki.wikilink_graph.2002-03-01.csv', delimiter = '\t')
df2 = pd.read_csv('enwiki.wikilink_graph.2003-03-01.csv', delimiter = '\t')
g1 = nx.from_pandas_edgelist(df1, 'page_id_from', 'page_id_to')
g2 = nx.from_pandas_edgelist(df2, 'page_id_from', 'page_id_to')

# %%
pos_train, neg_train = create_train_dataset(g1)

# %%
pos_test = create_test_dataset(g1, g2)
neg_test = create_negative(g1, pos_test, len(pos_test))

# %%
def create_feature_connection(pos_train, pos_test, neg_train, neg_test):
  train_has_connected = [1 for _ in range(len(pos_train))]
  train_not_connected = [0 for _ in range(len(neg_train))]
  test_has_connected = [1 for _ in range(len(pos_test))]
  test_not_connected = [0 for _ in range(len(neg_test))]

  train_index = np.concatenate((pos_train, neg_train))
  test_index = np.concatenate((pos_test, neg_test))

  train_data = np.concatenate((train_has_connected, train_not_connected))
  test_data = np.concatenate((test_has_connected, test_not_connected))

  #shuffle data
  train_mask = np.random.permutation(len(train_data))
  test_mask = np.random.permutation(len(test_data))

  train_index_s = train_index[train_mask]
  test_index_s = test_index[test_mask]
  train_data_s = train_data[train_mask]
  test_data_s = test_data[test_mask]

  df_train = pd.DataFrame()
  df_test = pd.DataFrame(index=test_index_s)
  df_train['index'] = train_index_s
  df_train['connected'] = train_data_s
  df_test['index'] = test_index_s
  df_test['connected'] = test_data_s

  return df_train, df_test

# %%
df_train_lbl, df_test_lbl = create_feature_connection(pos_train, pos_test, neg_train, neg_test)

# %%
def build_feature(G, edges):
  index = []
  cn_data, jc_data, pa_data = [], [], []
  for edge in edges:
    cn = len(list(nx.common_neighbors(G, edge[0], edge[1])))
    jc = list(nx.jaccard_coefficient(G, [edge]))[0]
    pa = list(nx.preferential_attachment(G, [edge]))[0]
    index.append(edge)
    cn_data.append(cn)
    jc_data.append(jc[2])
    pa_data.append(pa[2])
  df = pd.DataFrame()
  df['index'] = index
  df['preferential_attachment'] = pa_data
  df['common_neighbors'] = cn_data
  df['jaccard_coef'] = jc_data
  return df

# %%
edges_train = np.concatenate((pos_train, neg_train))
edges_test = np.concatenate((pos_test, neg_test))

# %%
features_train = build_feature(g1, edges_train)
features_test = build_feature(g1, edges_test)

# %%
features_train.fillna(0, inplace = True)
features_test.fillna(0, inplace = True)

# %%
train_df_data = df_train_lbl.merge(features_train, on='index', how='left')

# %%
test_df_data = df_test_lbl.merge(features_test, on='index', how = 'left')

# %%
x_train = train_df_data[['preferential_attachment', 'common_neighbors', 'jaccard_coef']].values
y_train = train_df_data['connected'].values

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
x_test = test_df_data[['preferential_attachment', 'common_neighbors', 'jaccard_coef']].values
y_test = test_df_data['connected'].values

# %%
y_pred = model.predict(x_test)

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.7201375543643168

# %% [markdown]
# ## Node embedding

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.parameter import Parameter
import numpy as np
import time

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
edges = list(g1.edges())
pos_train = np.empty(len(edges), dtype = object)
pos_train[:] = edges
pos_test = create_test_dataset(g1, g2)

# %%
class NodeEmbedding(nn.Module):

  def __init__(self, num_nodes, size, num_rels = 2):
    super(NodeEmbedding, self).__init__()
    self.node_embedding = nn.Embedding(num_nodes, size)
    self.relation_embedding = nn.Embedding(num_rels, size)
    self.init(num_nodes)

  def init(self, num_nodes):
    init_range = 6/np.sqrt(num_nodes)
    self.node_embedding.weight.data.uniform_(-init_range, init_range)
  
  def forward(self, h, t):
    self.node_embedding.weight.data[:-1, :].div_(self.node_embedding.weight.data[:-1, :].norm(p=2, dim=1, keepdim=True))
    self.relation_embedding.weight.data[:-1,:].div_(self.relation_embedding.weight.data[:-1,:].norm(p = 2, dim = 1, keepdim = True))
    return self.loss(h, t)
  def loss(self, h, t):
    h_v = self.node_embedding(h)
    t_v = self.node_embedding(t)
    l = torch.norm(h_v - t_v, p = 2, dim = 1)
    return torch.mean(l)
  def save_embedding(self):
    return self.node_embedding.weight.data.detach().cpu().numpy()

# %%
def train_one_step(epo, model, optimizer, h, t):
  start = time.time()
  optimizer.zero_grad()
  loss = model(h, t)
  loss.backward()
  optimizer.step()
  end = time.time()
  print('Epoch: %d: -> loss: %f, time: %fs'%(epo, loss, (end-start)))

# %%
def map_to_id(filename):
  node_mapping = dict()
  f = open(filename)
  lines = f.readlines()
  idx = 0
  for line in lines[1:]:
    tmp = line.strip().split('\t')
    if int(tmp[0]) not in node_mapping:
      node_mapping[int(tmp[0])] = idx
      idx += 1
    if int(tmp[2]) not in node_mapping:
      node_mapping[int(tmp[2])] = idx
      idx += 1
  return node_mapping

# %%
def rebuild_relation(relation, node_mapping):
  h = []
  t = []
  for e1, e2 in relation:
    h.append(node_mapping[e1])
    t.append(node_mapping[e2])
  return h, t

# %%
node_mapping = map_to_id('enwiki.wikilink_graph.2002-03-01.csv')

# %%
relation = pos_train

# %%
h, t = rebuild_relation(relation, node_mapping)

# %%
h = torch.LongTensor(h)
t = torch.LongTensor(t)

# %%
num_nodes = len(node_mapping)

# %%
model = NodeEmbedding(num_nodes = num_nodes, size = 50)

# %%
optimizer = optim.Adam(model.parameters(), weight_decay=5e-3)

# %%
model = model.to(device)
h = h.to(device)
t = t.to(device)

# %%
for epo in range(100):
  train_one_step(epo, model, optimizer, h, t)
# Out:
# Epoch: 0: -> loss: 1.407942, time: 0.192191s
# Epoch: 1: -> loss: 1.407938, time: 0.006254s
# Epoch: 2: -> loss: 1.407935, time: 0.006479s
# Epoch: 3: -> loss: 1.407931, time: 0.006423s
# Epoch: 4: -> loss: 1.407927, time: 0.006493s
# Epoch: 5: -> loss: 1.407924, time: 0.006500s
# Epoch: 6: -> loss: 1.407920, time: 0.006441s
# Epoch: 7: -> loss: 1.407917, time: 0.006374s
# Epoch: 8: -> loss: 1.407913, time: 0.006338s
# Epoch: 9: -> loss: 1.407909, time: 0.006494s
# Epoch: 10: -> loss: 1.407905, time: 0.006402s
# Epoch: 11: -> loss: 1.407902, time: 0.006251s
# Epoch: 12: -> loss: 1.407898, time: 0.006347s
# Epoch: 13: -> loss: 1.407894, time: 0.006335s
# Epoch: 14: -> loss: 1.407891, time: 0.006355s
# Epoch: 15: -> loss: 1.407887, time: 0.006431s
# Epoch: 16: -> loss: 1.407884, time: 0.006771s
# Epoch: 17: -> loss: 1.407880, time: 0.006416s
# Epoch: 18: -> loss: 1.407877, time: 0.006409s
# Epoch: 19: -> loss: 1.407873, time: 0.006392s
# Epoch: 20: -> loss: 1.407870, time: 0.006383s
# Epoch: 21: -> loss: 1.407866, time: 0.006378s
# Epoch: 22: -> loss: 1.407863, time: 0.006349s
# Epoch: 23: -> loss: 1.407859, time: 0.006506s
# Epoch: 24: -> loss: 1.407856, time: 0.006356s
# Epoch: 25: -> loss: 1.407852, time: 0.006465s
# Epoch: 26: -> loss: 1.407848, time: 0.006469s
# Epoch: 27: -> loss: 1.407845, time: 0.006387s
# Epoch: 28: -> loss: 1.407841, time: 0.007447s
# Epoch: 29: -> loss: 1.407838, time: 0.005161s
# Epoch: 30: -> loss: 1.407834, time: 0.004996s
# Epoch: 31: -> loss: 1.407830, time: 0.005020s
# Epoch: 32: -> loss: 1.407827, time: 0.005205s
# Epoch: 33: -> loss: 1.407823, time: 0.004689s
# Epoch: 34: -> loss: 1.407819, time: 0.004975s
# Epoch: 35: -> loss: 1.407815, time: 0.005077s
# Epoch: 89: -> loss: 1.407638, time: 0.004659s
# Epoch: 90: -> loss: 1.407635, time: 0.004579s
# Epoch: 91: -> loss: 1.407632, time: 0.004592s
# Epoch: 92: -> loss: 1.407629, time: 0.004630s
# Epoch: 93: -> loss: 1.407626, time: 0.004627s
# Epoch: 94: -> loss: 1.407623, time: 0.004596s
# Epoch: 95: -> loss: 1.407620, time: 0.004655s
# Epoch: 96: -> loss: 1.407617, time: 0.004599s
# Epoch: 97: -> loss: 1.407614, time: 0.004626s
# Epoch: 98: -> loss: 1.407611, time: 0.004706s
# Epoch: 99: -> loss: 1.407608, time: 0.004677s

# %%
emb = model.save_embedding()

# %%
f = open('embedding.txt', 'w')
for vct in emb:
  vct_s = list(map(str, vct))
  f.write(' '.join(vct_s) + '\n')

# %%
model_prediction = LinkPrediction(emb, 50)
optimizer_prediction = optim.Adam(model_prediction.parameters(), lr = 0.01, weight_decay=1e-2)
criterion = nn.CrossEntropyLoss()

# %%
edges_train = df_train_lbl.values
lbl_train = df_train_lbl['connected'].values

# %%
h_train, t_train, r_train = rebuild_relation(edges_train, node_mapping)

# %%
h_train = torch.LongTensor(h_train)
t_train = torch.LongTensor(t_train)
lbl_train = torch.LongTensor(r_train)

# %%
model_prediction = model_prediction.to(device)
h_train = h_train.to(device)
t_train = t_train.to(device)
r_train = lbl_train.to(device)

# %%
for epo in range(100):
  train_one_step_prediction(epo, model_prediction, optimizer_prediction, criterion, h_train, t_train, r_train)

# %%
edges_test = df_test_lbl.values

# %%
h_test, t_test, r_test = rebuild_relation(edges_test, node_mapping)

# %%
h_test = torch.LongTensor(h_test)
t_test = torch.LongTensor(t_test)
lbl_test = torch.LongTensor(lbl_test)

# %%
h_test.to(device)
t_test.to(device)
lbl_test.to(device)

# %%
model_prediction.eval()
y_pred = model_prediction(h_test, t_test, r_test)

# %%
y_pred

# %%
y_pred = y_pred.detach().numpy()

# %%
lbl = np.argmax(y_pred, axis = 1)

# %%
sum(lbl == lbl_test.numpy())/len(lbl)

# %% [markdown]
# ## Try Using GraphSAGE

# %%
# !pip install stellargraph
# Out:
# Installing collected packages: stellargraph
# Successfully installed stellargraph-1.2.1

# %%
import networkx as nx
import pandas as pd
import os

import stellargraph as sg
from stellargraph.data import EdgeSplitter
from stellargraph.mapper import GraphSAGELinkGenerator
from stellargraph.layer import GraphSAGE, link_classification

import tensorflow.keras as keras # DO NOT USE KERAS DIRECTLY
from sklearn import preprocessing, feature_extraction, model_selection

from stellargraph import globalvar

# %%
g_nx = nx.Graph()
h, t = rebuild_relation(pos_train, node_mapping)
g_nx.add_edges_from(zip(h, t))

# %%
for n in list(g_nx.nodes()):
  g_nx.nodes[n]['feature'] = emb[n]

# %%
edge_splitter_test = EdgeSplitter(g_nx)

# %%
G_test, edge_ids_test, edge_labels_test = edge_splitter_test.train_test_split(
        p=0.1, method="global", keep_connected=True
    )
# Out:
# ** Sampled 19586 positive and 19586 negative edges. **

# %%
edge_splitter_train = EdgeSplitter(G_test)
G_train, edge_ids_train, edge_labels_train = edge_splitter_train.train_test_split(
    p=0.1, method="global", keep_connected=True
)
# Out:
# ** Sampled 17627 positive and 17627 negative edges. **

# %%
G_train = sg.StellarGraph(G_train, node_features="feature")
G_test = sg.StellarGraph(G_test, node_features="feature")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Constructing a StellarGraph directly from a NetworkX graph has been replaced by the `StellarGraph.from_networkx` function
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Constructing a StellarGraph directly from a NetworkX graph has been replaced by the `StellarGraph.from_networkx` function

# %%
print(G_train.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 27654, Edges: 158650
#
#  Node types:
#   default: [27654]
#     Features: float32 vector, length 50
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [158650]
#         Weights: all 1 (default)
#         Features: none

# %%
print(G_test.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 27654, Edges: 176277
#
#  Node types:
#   default: [27654]
#     Features: float32 vector, length 50
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [176277]
#         Weights: all 1 (default)
#         Features: none

# %%
batch_size = 20
epochs = 20

# %%
num_samples = [20, 10]


train_gen = GraphSAGELinkGenerator(G_train, batch_size, num_samples)
test_gen = GraphSAGELinkGenerator(G_test,  batch_size, num_samples)

# %%
layer_sizes = [30, 30]
assert len(layer_sizes) == len(num_samples)

# %%
graphsage = GraphSAGE(layer_sizes=layer_sizes, generator=train_gen,
                      bias=True, dropout=0.3)

# %%
train_gen = train_gen.flow(edge_ids_train,edge_labels_train)
test_gen = test_gen.flow(edge_ids_test, edge_labels_test)

# %%
x_inp, x_out = graphsage.build()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: The 'build' method is deprecated, use 'in_out_tensors' instead.
#   """Entry point for launching an IPython kernel.

# %%
prediction = link_classification(
        output_dim=1, output_act="relu", edge_embedding_method='ip'
    )(x_out)
# Out:
# link_classification: using 'ip' method to combine node embeddings into edge embeddings

# %%
model = keras.Model(inputs=x_inp, outputs=prediction)

model.compile(
        optimizer=keras.optimizers.Adam(lr=1e-3),
        loss=keras.losses.binary_crossentropy,
        metrics=["acc"],
    )

# %%
init_train_metrics = model.evaluate_generator(train_gen)
init_test_metrics = model.evaluate_generator(test_gen)

print("\nTrain Set Metrics of the initial (untrained) model:")
for name, val in zip(model.metrics_names, init_train_metrics):
    print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the initial (untrained) model:")
for name, val in zip(model.metrics_names, init_test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# Train Set Metrics of the initial (untrained) model:
# 	loss: 0.8778
# 	acc: 0.5577
#
# Test Set Metrics of the initial (untrained) model:
# 	loss: 0.8872
# 	acc: 0.5573

# %%
history = model.fit_generator(
            train_gen,
            epochs=epochs,
            validation_data=test_gen,
            verbose=2
        )
# Out:
# Epoch 1/20
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 1763/1763 - 111s - loss: 0.6580 - acc: 0.6412 - val_loss: 0.5600 - val_acc: 0.7398
# Epoch 2/20
# 1763/1763 - 107s - loss: 0.6060 - acc: 0.7052 - val_loss: 0.5486 - val_acc: 0.7382
# Epoch 3/20
# 1763/1763 - 107s - loss: 0.5855 - acc: 0.7272 - val_loss: 0.5423 - val_acc: 0.7535
# Epoch 4/20
# 1763/1763 - 107s - loss: 0.5672 - acc: 0.7356 - val_loss: 0.5725 - val_acc: 0.7018
# Epoch 5/20
# 1763/1763 - 107s - loss: 0.5691 - acc: 0.7351 - val_loss: 0.5632 - val_acc: 0.7049
# Epoch 6/20
# 1763/1763 - 107s - loss: 0.5570 - acc: 0.7271 - val_loss: 0.5474 - val_acc: 0.7165
# Epoch 7/20
# 1763/1763 - 107s - loss: 0.5569 - acc: 0.7350 - val_loss: 0.5372 - val_acc: 0.7224
# Epoch 8/20
# 1763/1763 - 108s - loss: 0.5531 - acc: 0.7360 - val_loss: 0.5467 - val_acc: 0.7177
# Epoch 9/20
# 1763/1763 - 106s - loss: 0.5492 - acc: 0.7426 - val_loss: 0.5415 - val_acc: 0.7275
# Epoch 10/20
# 1763/1763 - 107s - loss: 0.5561 - acc: 0.7434 - val_loss: 0.5874 - val_acc: 0.6888
# Epoch 11/20
# 1763/1763 - 107s - loss: 0.5432 - acc: 0.7441 - val_loss: 0.5209 - val_acc: 0.7479
# Epoch 12/20
# 1763/1763 - 107s - loss: 0.5382 - acc: 0.7475 - val_loss: 0.5161 - val_acc: 0.7519
# Epoch 13/20
# 1763/1763 - 108s - loss: 0.5299 - acc: 0.7512 - val_loss: 0.5165 - val_acc: 0.7421
# Epoch 14/20
# 1763/1763 - 107s - loss: 0.5324 - acc: 0.7496 - val_loss: 0.5340 - val_acc: 0.7269
# Epoch 15/20
# 1763/1763 - 108s - loss: 0.5379 - acc: 0.7412 - val_loss: 0.5155 - val_acc: 0.7445
# Epoch 16/20
# 1763/1763 - 106s - loss: 0.5261 - acc: 0.7575 - val_loss: 0.5327 - val_acc: 0.7275
# Epoch 17/20
# 1763/1763 - 105s - loss: 0.5331 - acc: 0.7570 - val_loss: 0.5626 - val_acc: 0.6984
# Epoch 18/20
# 1763/1763 - 105s - loss: 0.5350 - acc: 0.7408 - val_loss: 0.5250 - val_acc: 0.7336
# Epoch 19/20
# 1763/1763 - 105s - loss: 0.5250 - acc: 0.7562 - val_loss: 0.5045 - val_acc: 0.7587
# Epoch 20/20
# 1763/1763 - 104s - loss: 0.5302 - acc: 0.7604 - val_loss: 0.5129 - val_acc: 0.7471

# %% [markdown]
# #Final Code

# %% [markdown]
# ## Data and library

# %%
from google.colab import drive
drive.mount('/content/GDrive')
# Out:
# Mounted at /content/GDrive

# %%
# %%bash
# cp /content/GDrive/MyDrive/WikiLinksGraph/enwiki.wikilink_graph.2002-03-01.csv.gz /content/
# gzip -d /content/enwiki.wikilink_graph.2002-03-01.csv.gz
# cp /content/GDrive/MyDrive/WikiLinksGraph/enwiki.wikilink_graph.2003-03-01.csv.gz /content/
# gzip -d /content/enwiki.wikilink_graph.2003-03-01.csv.gz

# %%
import pandas as pd
import numpy as np
import networkx as nx
from collections import defaultdict
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from time import time

# %% [markdown]
# ##Some function

# %% [markdown]
# ### Create Negative Sampling

# %%
def create_negative(g, possitives, from_pos = 10000):
  print(f'total negative: {from_pos}')
  negatives = []
  pos2neg = np.random.choice(possitives, from_pos, replace = False)
  nodes = set(g.nodes())
  i = 1
  for e1, _ in pos2neg:
    print(f'Create Negative {i}/{from_pos}|')
    i += 1
    neighs = set(nx.neighbors(g, e1))
    indicates =list(nodes - neighs)
    e2 = np.random.choice(indicates, 1)[0]
    negatives.append((e1, e2))
  negatives = list(set(negatives))
  ret = np.empty(len(negatives), dtype = object)
  ret[:] = negatives
  return ret

# %% [markdown]
# ### Create Train set

# %%
def create_train_dataset(g, neg_rate = 1.0):
  nodes = np.array(g.nodes())
  edges = list(g.edges())
  possitives = np.empty(len(edges), dtype = object)
  possitives[:] = edges

  from_pos = int(len(edges)*neg_rate)

  negatives = create_negative(g, possitives, from_pos)
  return possitives, negatives

# %% [markdown]
# ### Create test set

# %%
def create_test_dataset(g_curr, g_aft):
  nodes_curr = set(g_curr.nodes())
  egdes_curr = set(g_curr.edges())
  edges_aft = set(g_aft.edges())
  new_edges = edges_aft - egdes_curr
  test = []
  for new_edge in new_edges:
    if (new_edge[0] in nodes_curr) and (new_edge[1] in nodes_curr):
      test.append(new_edge)
  ret = np.empty(len(test), dtype = object)
  ret[:] = test
  return ret

# %% [markdown]
# ### Create train and test label for edges

# %%
def create_feature_connection(pos_train, pos_test, neg_train, neg_test):
  train_has_connected = [1 for _ in range(len(pos_train))]
  train_not_connected = [0 for _ in range(len(neg_train))]
  test_has_connected = [1 for _ in range(len(pos_test))]
  test_not_connected = [0 for _ in range(len(neg_test))]

  train_index = np.concatenate((pos_train, neg_train))
  test_index = np.concatenate((pos_test, neg_test))

  train_data = np.concatenate((train_has_connected, train_not_connected))
  test_data = np.concatenate((test_has_connected, test_not_connected))

  #shuffle data
  train_mask = np.random.permutation(len(train_data))
  test_mask = np.random.permutation(len(test_data))

  train_index_s = train_index[train_mask]
  test_index_s = test_index[test_mask]
  train_data_s = train_data[train_mask]
  test_data_s = test_data[test_mask]

  df_train = pd.DataFrame()
  df_test = pd.DataFrame(index=test_index_s)
  df_train['index'] = train_index_s
  df_train['connected'] = train_data_s
  df_test['index'] = test_index_s
  df_test['connected'] = test_data_s

  return df_train, df_test

# %% [markdown]
# ### Build features vector (function)

# %%
def build_feature(G, edges):
  index = []
  cn_data, jc_data, pa_data = [], [], []
  for edge in edges:
    cn = len(list(nx.common_neighbors(G, edge[0], edge[1])))
    jc = list(nx.jaccard_coefficient(G, [edge]))[0]
    pa = list(nx.preferential_attachment(G, [edge]))[0]
    index.append(edge)
    cn_data.append(cn)
    jc_data.append(jc[2])
    pa_data.append(pa[2])
  df = pd.DataFrame()
  df['index'] = index
  df['preferential_attachment'] = pa_data
  df['common_neighbors'] = cn_data
  df['jaccard_coef'] = jc_data
  return df

# %% [markdown]
# ##Repair data

# %% [markdown]
# ### Load graph at time $t$ and $t + 1$ as $g_1$ and $g_2$. <br>
# $g_1$ for training, $g_2$ for testing

# %%
df1 = pd.read_csv('enwiki.wikilink_graph.2002-03-01.csv', delimiter = '\t')
df2 = pd.read_csv('enwiki.wikilink_graph.2003-03-01.csv', delimiter = '\t')
g1 = nx.from_pandas_edgelist(df1, 'page_id_from', 'page_id_to')
g2 = nx.from_pandas_edgelist(df2, 'page_id_from', 'page_id_to')

# %%
start = time()
pos_train, neg_train = create_train_dataset(g1)
end = time()
print(f'total time: {end - start} s')
# Out:
# Streaming output truncated to the last 5000 lines.
# Create Negative 190864/195863|
# Create Negative 190865/195863|
# Create Negative 190866/195863|
# Create Negative 190867/195863|
# Create Negative 190868/195863|
# Create Negative 190869/195863|
# Create Negative 190870/195863|
# Create Negative 190871/195863|
# Create Negative 190872/195863|
# Create Negative 190873/195863|
# Create Negative 191968/195863|
# Create Negative 191969/195863|
# Create Negative 191970/195863|
# Create Negative 191971/195863|
# Create Negative 191972/195863|
# Create Negative 191973/195863|
# Create Negative 191974/195863|
# Create Negative 191975/195863|
# Create Negative 191976/195863|
# Create Negative 191977/195863|
# Create Negative 191978/195863|
# Create Negative 191979/195863|
# Create Negative 191980/195863|
# Create Negative 191981/195863|
# Create Negative 191982/195863|
# Create Negative 191983/195863|
# Create Negative 191984/195863|
# Create Negative 191985/195863|
# Create Negative 191986/195863|
# Create Negative 191987/195863|
# Create Negative 191988/195863|
# Create Negative 191989/195863|
# Create Negative 191990/195863|
# Create Negative 191991/195863|
# Create Negative 191992/195863|
# Create Negative 191993/195863|
# Create Negative 191994/195863|
# Create Negative 191995/195863|
# Create Negative 191996/195863|
# Create Negative 191997/195863|
# Create Negative 191998/195863|
# Create Negative 191999/195863|
# Create Negative 192000/195863|
# Create Negative 192001/195863|
# Create Negative 192002/195863|
# Create Negative 192003/195863|
# Create Negative 192004/195863|
# Create Negative 192005/195863|
# Create Negative 192006/195863|
# Create Negative 192007/195863|
# Create Negative 192008/195863|
# Create Negative 192009/195863|
# Create Negative 192010/195863|
# Create Negative 192011/195863|
# Create Negative 192012/195863|
# Create Negative 192013/195863|
# Create Negative 192014/195863|
# Create Negative 192015/195863|
# Create Negative 192016/195863|
# Create Negative 192017/195863|
# Create Negative 192018/195863|
# Create Negative 192019/195863|
# Create Negative 192020/195863|
# Create Negative 192021/195863|
# Create Negative 192022/195863|
# Create Negative 192023/195863|
# Create Negative 192024/195863|
# Create Negative 192025/195863|
# Create Negative 192026/195863|
# Create Negative 192027/195863|
# Create Negative 192028/195863|
# Create Negative 192029/195863|
# Create Negative 192030/195863|
# Create Negative 192031/195863|
# Create Negative 192032/195863|
# Create Negative 192033/195863|
# Create Negative 192034/195863|
# Create Negative 192035/195863|
# Create Negative 192036/195863|
# Create Negative 192037/195863|
# Create Negative 192038/195863|
# Create Negative 192039/195863|
# Create Negative 192040/195863|
# Create Negative 192041/195863|
# Create Negative 192042/195863|
# Create Negative 192043/195863|
# Create Negative 192044/195863|
# Create Negative 192045/195863|
# Create Negative 192046/195863|
# Create Negative 192047/195863|
# Create Negative 192048/195863|
# Create Negative 192049/195863|
# Create Negative 192050/195863|
# Create Negative 192051/195863|
# Create Negative 192052/195863|
# Create Negative 192053/195863|
# Create Negative 192054/195863|
# Create Negative 192055/195863|
# Create Negative 192056/195863|
# Create Negative 192057/195863|
# Create Negative 192058/195863|
# Create Negative 192059/195863|
# Create Negative 192060/195863|
# Create Negative 192061/195863|
# Create Negative 192062/195863|
# Create Negative 192063/195863|
# Create Negative 192064/195863|
# Create Negative 192065/195863|
# Create Negative 192066/195863|
# Create Negative 192067/195863|
# Create Negative 192068/195863|
# Create Negative 192069/195863|
# Create Negative 192070/195863|
# Create Negative 192071/195863|
# Create Negative 192072/195863|
# Create Negative 192073/195863|
# Create Negative 192074/195863|
# Create Negative 192075/195863|
# Create Negative 192076/195863|
# Create Negative 192077/195863|
# Create Negative 192078/195863|
# Create Negative 192079/195863|
# Create Negative 192080/195863|
# Create Negative 192081/195863|
# Create Negative 192082/195863|
# Create Negative 192083/195863|
# Create Negative 192084/195863|
# Create Negative 192085/195863|
# Create Negative 192086/195863|
# Create Negative 192087/195863|
# Create Negative 192088/195863|
# Create Negative 192089/195863|
# Create Negative 192090/195863|
# Create Negative 192091/195863|
# Create Negative 192092/195863|
# Create Negative 192093/195863|
# Create Negative 192094/195863|
# Create Negative 192095/195863|
# Create Negative 192096/195863|
# Create Negative 192097/195863|
# Create Negative 192098/195863|
# Create Negative 192099/195863|
# Create Negative 192100/195863|
# Create Negative 192101/195863|
# Create Negative 192102/195863|
# Create Negative 192103/195863|
# Create Negative 192104/195863|
# Create Negative 192105/195863|
# Create Negative 192106/195863|
# Create Negative 192107/195863|
# Create Negative 192108/195863|
# Create Negative 192109/195863|
# Create Negative 192110/195863|
# Create Negative 192111/195863|
# Create Negative 192112/195863|
# Create Negative 192113/195863|
# Create Negative 192114/195863|
# Create Negative 192115/195863|
# Create Negative 192116/195863|
# Create Negative 192117/195863|
# Create Negative 192118/195863|
# Create Negative 192119/195863|
# Create Negative 192120/195863|
# Create Negative 192121/195863|
# Create Negative 192122/195863|
# Create Negative 192123/195863|
# Create Negative 192124/195863|
# Create Negative 192125/195863|
# Create Negative 192126/195863|
# Create Negative 192127/195863|
# Create Negative 192128/195863|
# Create Negative 192129/195863|
# Create Negative 192130/195863|
# Create Negative 192131/195863|
# Create Negative 192132/195863|
# Create Negative 192133/195863|
# Create Negative 192134/195863|
# Create Negative 192135/195863|
# Create Negative 192136/195863|
# Create Negative 192137/195863|
# Create Negative 192138/195863|
# Create Negative 192139/195863|
# Create Negative 192140/195863|
# Create Negative 192141/195863|
# Create Negative 192142/195863|
# Create Negative 192143/195863|
# Create Negative 192144/195863|
# Create Negative 192145/195863|
# Create Negative 192146/195863|
# Create Negative 192147/195863|
# Create Negative 192148/195863|
# Create Negative 192149/195863|
# Create Negative 192150/195863|
# Create Negative 192151/195863|
# Create Negative 192152/195863|
# Create Negative 192153/195863|
# Create Negative 192154/195863|
# Create Negative 192155/195863|
# Create Negative 192156/195863|
# Create Negative 192157/195863|
# Create Negative 192158/195863|
# Create Negative 192159/195863|
# Create Negative 192160/195863|
# Create Negative 192161/195863|
# Create Negative 192162/195863|
# Create Negative 192163/195863|
# Create Negative 192164/195863|
# Create Negative 192165/195863|
# Create Negative 192166/195863|
# Create Negative 192167/195863|
# Create Negative 192168/195863|
# Create Negative 192169/195863|
# Create Negative 192170/195863|
# Create Negative 192171/195863|
# Create Negative 192172/195863|
# Create Negative 192173/195863|
# Create Negative 192174/195863|
# Create Negative 192175/195863|
# Create Negative 192176/195863|
# Create Negative 192177/195863|
# Create Negative 192178/195863|
# Create Negative 192179/195863|
# Create Negative 192180/195863|
# Create Negative 192181/195863|
# Create Negative 192182/195863|
# Create Negative 192183/195863|
# Create Negative 192184/195863|
# Create Negative 192185/195863|
# Create Negative 192186/195863|
# Create Negative 192187/195863|
# Create Negative 192188/195863|
# Create Negative 192189/195863|
# Create Negative 192190/195863|
# Create Negative 192191/195863|
# Create Negative 192192/195863|
# Create Negative 192193/195863|
# Create Negative 192194/195863|
# Create Negative 192195/195863|
# Create Negative 192196/195863|
# Create Negative 192197/195863|
# Create Negative 192198/195863|
# Create Negative 192199/195863|
# Create Negative 192200/195863|
# Create Negative 192201/195863|
# Create Negative 192202/195863|
# Create Negative 192203/195863|
# Create Negative 192204/195863|
# Create Negative 192205/195863|
# Create Negative 192206/195863|
# Create Negative 192207/195863|
# Create Negative 192208/195863|
# Create Negative 192209/195863|
# Create Negative 192210/195863|
# Create Negative 192211/195863|
# Create Negative 192212/195863|
# Create Negative 192213/195863|
# Create Negative 192214/195863|
# Create Negative 192215/195863|
# Create Negative 192216/195863|
# Create Negative 192217/195863|
# Create Negative 192218/195863|
# Create Negative 192219/195863|
# Create Negative 192220/195863|
# Create Negative 192221/195863|
# Create Negative 192222/195863|
# Create Negative 192223/195863|
# Create Negative 192224/195863|
# Create Negative 192225/195863|
# Create Negative 192226/195863|
# Create Negative 192227/195863|
# Create Negative 192228/195863|
# Create Negative 192229/195863|
# Create Negative 192230/195863|
# Create Negative 192231/195863|
# Create Negative 192232/195863|
# Create Negative 192233/195863|
# Create Negative 192234/195863|
# Create Negative 192235/195863|
# Create Negative 192236/195863|
# Create Negative 192237/195863|
# Create Negative 192238/195863|
# Create Negative 192239/195863|
# Create Negative 192240/195863|
# Create Negative 192241/195863|
# Create Negative 192242/195863|
# Create Negative 192243/195863|
# Create Negative 192244/195863|
# Create Negative 192245/195863|
# Create Negative 192246/195863|
# Create Negative 192247/195863|
# Create Negative 192248/195863|
# Create Negative 192249/195863|
# Create Negative 192250/195863|
# Create Negative 192251/195863|
# Create Negative 192252/195863|
# Create Negative 192253/195863|
# Create Negative 192254/195863|
# Create Negative 192255/195863|
# Create Negative 192256/195863|
# Create Negative 192257/195863|
# Create Negative 192258/195863|
# Create Negative 192259/195863|
# Create Negative 192260/195863|
# Create Negative 192261/195863|
# Create Negative 192262/195863|
# Create Negative 192263/195863|
# Create Negative 192264/195863|
# Create Negative 192265/195863|
# Create Negative 192266/195863|
# Create Negative 192267/195863|
# Create Negative 192268/195863|
# Create Negative 192269/195863|
# Create Negative 192270/195863|
# Create Negative 192271/195863|
# Create Negative 192272/195863|
# Create Negative 192273/195863|
# Create Negative 192274/195863|
# Create Negative 192275/195863|
# Create Negative 192276/195863|
# Create Negative 192277/195863|
# Create Negative 192278/195863|
# Create Negative 192279/195863|
# Create Negative 192280/195863|
# Create Negative 192281/195863|
# Create Negative 192282/195863|
# Create Negative 192283/195863|
# Create Negative 192284/195863|
# Create Negative 192285/195863|
# Create Negative 192286/195863|
# Create Negative 192287/195863|
# Create Negative 192288/195863|
# Create Negative 192289/195863|
# Create Negative 192290/195863|
# Create Negative 192291/195863|
# Create Negative 192292/195863|
# Create Negative 192293/195863|
# Create Negative 192294/195863|
# Create Negative 192295/195863|
# Create Negative 192296/195863|
# Create Negative 192297/195863|
# Create Negative 192298/195863|
# Create Negative 192299/195863|
# Create Negative 192300/195863|
# Create Negative 192301/195863|
# Create Negative 192302/195863|
# Create Negative 192303/195863|
# Create Negative 192304/195863|
# Create Negative 192305/195863|
# Create Negative 192306/195863|
# Create Negative 192307/195863|
# Create Negative 192308/195863|
# Create Negative 192309/195863|
# Create Negative 192310/195863|
# Create Negative 192311/195863|
# Create Negative 192312/195863|
# Create Negative 192313/195863|
# Create Negative 192314/195863|
# Create Negative 192315/195863|
# Create Negative 192316/195863|
# Create Negative 192317/195863|
# Create Negative 192318/195863|
# Create Negative 192319/195863|
# Create Negative 192320/195863|
# Create Negative 192321/195863|
# Create Negative 192322/195863|
# Create Negative 192323/195863|
# Create Negative 192324/195863|
# Create Negative 192325/195863|
# Create Negative 192326/195863|
# Create Negative 192327/195863|
# Create Negative 192328/195863|
# Create Negative 192329/195863|
# Create Negative 192330/195863|
# Create Negative 192331/195863|
# Create Negative 192332/195863|
# Create Negative 192333/195863|
# Create Negative 192334/195863|
# Create Negative 192335/195863|
# Create Negative 192336/195863|
# Create Negative 192337/195863|
# Create Negative 192338/195863|
# Create Negative 192339/195863|
# Create Negative 192340/195863|
# Create Negative 192341/195863|
# Create Negative 192342/195863|
# Create Negative 192343/195863|
# Create Negative 192344/195863|
# Create Negative 192345/195863|
# Create Negative 192346/195863|
# Create Negative 192347/195863|
# Create Negative 192348/195863|
# Create Negative 192349/195863|
# Create Negative 192350/195863|
# Create Negative 192351/195863|
# Create Negative 192352/195863|
# Create Negative 192353/195863|
# Create Negative 192354/195863|
# Create Negative 192355/195863|
# Create Negative 192356/195863|
# Create Negative 192357/195863|
# Create Negative 192358/195863|
# Create Negative 192359/195863|
# Create Negative 192360/195863|
# Create Negative 192361/195863|
# Create Negative 192362/195863|
# Create Negative 192363/195863|
# Create Negative 192364/195863|
# Create Negative 192365/195863|
# Create Negative 192366/195863|
# Create Negative 192367/195863|
# Create Negative 192368/195863|
# Create Negative 192369/195863|
# Create Negative 192370/195863|
# Create Negative 192371/195863|
# Create Negative 192372/195863|
# Create Negative 192373/195863|
# Create Negative 192374/195863|
# Create Negative 192375/195863|
# Create Negative 192376/195863|
# Create Negative 192377/195863|
# Create Negative 192378/195863|
# Create Negative 192379/195863|
# Create Negative 192380/195863|
# Create Negative 192381/195863|
# Create Negative 192382/195863|
# Create Negative 192383/195863|
# Create Negative 192384/195863|
# Create Negative 192385/195863|
# Create Negative 192386/195863|
# Create Negative 192387/195863|
# Create Negative 192388/195863|
# Create Negative 192389/195863|
# Create Negative 192390/195863|
# Create Negative 192391/195863|
# Create Negative 192392/195863|
# Create Negative 192393/195863|
# Create Negative 192394/195863|
# Create Negative 192395/195863|
# Create Negative 192396/195863|
# Create Negative 192397/195863|
# Create Negative 192398/195863|
# Create Negative 192399/195863|
# Create Negative 192400/195863|
# Create Negative 192401/195863|
# Create Negative 192402/195863|
# Create Negative 192403/195863|
# Create Negative 192404/195863|
# Create Negative 192405/195863|
# Create Negative 152760/152830|
# Create Negative 152761/152830|
# Create Negative 152762/152830|
# Create Negative 152763/152830|
# Create Negative 152764/152830|
# Create Negative 152765/152830|
# Create Negative 152766/152830|
# Create Negative 152767/152830|
# Create Negative 152768/152830|
# Create Negative 152769/152830|
# Create Negative 152770/152830|
# Create Negative 152771/152830|
# Create Negative 152772/152830|
# Create Negative 152773/152830|
# Create Negative 152774/152830|
# Create Negative 152775/152830|
# Create Negative 152776/152830|
# Create Negative 152777/152830|
# Create Negative 152778/152830|
# Create Negative 152779/152830|
# Create Negative 152780/152830|
# Create Negative 152781/152830|
# Create Negative 152782/152830|
# Create Negative 152783/152830|
# Create Negative 152784/152830|
# Create Negative 152785/152830|
# Create Negative 152786/152830|
# Create Negative 152787/152830|
# Create Negative 152788/152830|
# Create Negative 152789/152830|
# Create Negative 152790/152830|
# Create Negative 152791/152830|
# Create Negative 152792/152830|
# Create Negative 152793/152830|
# Create Negative 152794/152830|
# Create Negative 152795/152830|
# Create Negative 152796/152830|
# Create Negative 152797/152830|
# Create Negative 152798/152830|
# Create Negative 152799/152830|
# Create Negative 152800/152830|
# Create Negative 152801/152830|
# Create Negative 152802/152830|
# Create Negative 152803/152830|
# Create Negative 152804/152830|
# Create Negative 152805/152830|
# Create Negative 152806/152830|
# Create Negative 152807/152830|
# Create Negative 152808/152830|
# Create Negative 152809/152830|
# Create Negative 152810/152830|
# Create Negative 152811/152830|
# Create Negative 152812/152830|
# Create Negative 152813/152830|
# Create Negative 152814/152830|
# Create Negative 152815/152830|
# Create Negative 152816/152830|
# Create Negative 152817/152830|
# Create Negative 152818/152830|
# Create Negative 152819/152830|
# Create Negative 152820/152830|
# Create Negative 152821/152830|
# Create Negative 152822/152830|
# Create Negative 152823/152830|
# Create Negative 152824/152830|
# Create Negative 152825/152830|
# Create Negative 152826/152830|
# Create Negative 152827/152830|
# Create Negative 152828/152830|
# Create Negative 152829/152830|
# Create Negative 152830/152830|
# total time: 938.545473575592 s

# %% [markdown]
# ### df_train_lbl and df_test_lbl contain edges with their label

# %%
df_train_lbl, df_test_lbl = create_feature_connection(pos_train, pos_test, neg_train, neg_test)

# %% [markdown]
# ### Create data for training and testing

# %%
edges_train = np.concatenate((pos_train, neg_train))
edges_test = np.concatenate((pos_test, neg_test))

# %%
features_train = build_feature(g1, edges_train)
features_test = build_feature(g1, edges_test)

# %%
features_train.fillna(0, inplace = True)
features_test.fillna(0, inplace = True)

# %%
train_df_data = df_train_lbl.merge(features_train, on='index', how='left')
test_df_data = df_test_lbl.merge(features_test, on='index', how = 'left')

# %%
x_train = train_df_data[['preferential_attachment', 'common_neighbors', 'jaccard_coef']].values
y_train = train_df_data['connected'].values

# %%
x_test = test_df_data[['preferential_attachment', 'common_neighbors', 'jaccard_coef']].values
y_test = test_df_data['connected'].values

# %% [markdown]
# ## Model and (train and test)

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = model.predict(x_test)

# %%
print(f'accuracy score on test: {accuracy_score(y_pred, y_test)}')
# Out:
# accuracy score on test: 0.7185218531639623

# %% [markdown]
# ## Using community

# %%
import networkx.algorithms.community as nxcom

# %%
 communities = list(nxcom.label_propagation_communities(g1))

# %%
for c, v_c in enumerate(communities):
  for v in v_c:
    g1.nodes[v]['community'] = c + 1

# %% [markdown]
# ## Rebuild feature

# %%
def rebuild_feature(G, edges):
  index = []
  cn_data, jc_data, pa_data = [], [], []
  rai_data, adamicadar_data, cnsh_data = [], [], []
  wic_data, raish_data = [], []
  for edge in edges:
    try:
      cn = len(list(nx.common_neighbors(G, edge[0], edge[1])))
    except:
      cn = 0
    jc = list(nx.jaccard_coefficient(G, [edge]))[0]
    try:
      pa = list(nx.preferential_attachment(G, [edge]))[0]
    except:
      pa = [0, 0, 0]
    ##
    try:
      rai = list(nx.resource_allocation_index(G, [edge]))[0]
    except:
      rai = [0, 0, 0]
    try:
      adamicadar = list(nx.adamic_adar_index(G, [edge]))[0]
    except:
      adamicadar = [0, 0 , 0]
    try:
      cnsh = list(nx.cn_soundarajan_hopcroft(G, [edge]))[0]
    except:
      cnsh = [0, 0, 0]
    ##
    try:
      wic = list(nx.within_inter_cluster(G, [edge]))[0]
    except:
      wic = [0, 0, 0]
    try:
      raish = list(nx.ra_index_soundarajan_hopcroft(G, [edge]))[0]
    except:
      raish = [0, 0, 0]
    ##
    index.append(edge)
    cn_data.append(cn)
    jc_data.append(jc[2])
    pa_data.append(pa[2])

    rai_data.append(rai[2])
    adamicadar_data.append(adamicadar[2])
    cnsh_data.append(cnsh[2])

    wic_data.append(wic[2])
    raish_data.append(raish[2])

  df = pd.DataFrame()
  df['index'] = index
  df['preferential_attachment'] = pa_data
  df['common_neighbors'] = cn_data
  df['jaccard_coef'] = jc_data

  df['resource_allocation_index'] = rai_data
  df['adamic_adar_index'] = adamicadar_data
  df['cn_soundarajan_hopcroft'] = cnsh_data

  df['within_inter_cluster'] = wic_data
  df['ra_index_soundarajan_hopcroft'] = raish_data
  return df

# %%
start = time()
features_train = rebuild_feature(g1, edges_train)
end = time()
print(f'time to build train: {end - start}')
# Out:
# time to build train: 570.4147069454193

# %%
start = time()
features_test = rebuild_feature(g1, edges_test)
end = time()
print(f'time to build test: {end - start}')
# Out:
# time to build test: 404.86494970321655

# %%
features_train.fillna(0, inplace = True)
features_test.fillna(0, inplace = True)

# %%
train_df_data = df_train_lbl.merge(features_train, on='index', how='left')
test_df_data = df_test_lbl.merge(features_test, on='index', how = 'left')

# %%
col = ['preferential_attachment', 'common_neighbors', 'jaccard_coef',\
       'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft',\
       'within_inter_cluster', 'ra_index_soundarajan_hopcroft']

# %%
data_train_y = train_df_data['connected'].values
data_test_y = test_df_data['connected'].values
model_list = []
score_list = []
for heu in col:
  model = LogisticRegression()
  data_train_x = train_df_data[[heu]].values
  data_test_x = test_df_data[[heu]].values
  model.fit(data_train_x, data_train_y)
  pred = model.predict(data_test_x)
  pred1 = model.predict(data_train_x)
  score1 = accuracy_score(pred1, data_train_y)
  score = accuracy_score(pred, data_test_y)
  model_list.append(model)
  score_list.append(score1)
  print(f'heuristic: {heu} | score: {score}')
# Out:
# heuristic: preferential_attachment | score: 0.5861958727238327
# heuristic: common_neighbors | score: 0.7295936009603778
# heuristic: jaccard_coef | score: 0.6900432561507898
# heuristic: resource_allocation_index | score: 0.6692013596654336
# heuristic: adamic_adar_index | score: 0.7025797107122586
# heuristic: cn_soundarajan_hopcroft | score: 0.7202344835685346
# heuristic: within_inter_cluster | score: 0.6942025014190366
# heuristic: ra_index_soundarajan_hopcroft | score: 0.6566159728066914

# %%
score_list
# Out:
# [0.6180998643161765,
#  0.8634729437257092,
#  0.8316626251114728,
#  0.8151454832107239,
#  0.8457471681431759,
#  0.856742412821227,
#  0.7930093445525883,
#  0.7929914577961983]

# %% [markdown]
# ### With 3 col

# %%
import itertools
cbn = list(itertools.combinations(col, 3))

# %%
train_y = train_df_data['connected'].values
best_score = 0.0
best_model = None
best_col = None
for col_train in cbn:
  train_x = train_df_data[list(col_train)].values
  model = LogisticRegression()
  model.fit(train_x, train_y)
  pred = model.predict(train_x)
  score = accuracy_score(pred, train_y)
  print(f'train on col: {col_train} | score: {score}')
  if score > best_score:
    best_score = score
    best_model = model
    best_col = col_train
# Out:
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef') | score: 0.8602047778081569
# train on col: ('preferential_attachment', 'common_neighbors', 'resource_allocation_index') | score: 0.8602047778081569
# train on col: ('preferential_attachment', 'common_neighbors', 'adamic_adar_index') | score: 0.8602686590809785
# train on col: ('preferential_attachment', 'common_neighbors', 'cn_soundarajan_hopcroft') | score: 0.8537655455077411
# train on col: ('preferential_attachment', 'common_neighbors', 'within_inter_cluster') | score: 0.8603785348702316
# train on col: ('preferential_attachment', 'common_neighbors', 'ra_index_soundarajan_hopcroft') | score: 0.8602047778081569
# train on col: ('preferential_attachment', 'jaccard_coef', 'resource_allocation_index') | score: 0.5004791095461619
# train on col: ('preferential_attachment', 'jaccard_coef', 'adamic_adar_index') | score: 0.8489412317842551
# train on col: ('preferential_attachment', 'jaccard_coef', 'cn_soundarajan_hopcroft') | score: 0.8539827418353345
# train on col: ('preferential_attachment', 'jaccard_coef', 'within_inter_cluster') | score: 0.7931319965964058
# train on col: ('preferential_attachment', 'jaccard_coef', 'ra_index_soundarajan_hopcroft') | score: 0.5004791095461619
# train on col: ('preferential_attachment', 'resource_allocation_index', 'adamic_adar_index') | score: 0.8483867423361637
# train on col: ('preferential_attachment', 'resource_allocation_index', 'cn_soundarajan_hopcroft') | score: 0.8539878523371602
# train on col: ('preferential_attachment', 'resource_allocation_index', 'within_inter_cluster') | score: 0.8371819670832578
# train on col: ('preferential_attachment', 'resource_allocation_index', 'ra_index_soundarajan_hopcroft') | score: 0.5004791095461619
# train on col: ('preferential_attachment', 'adamic_adar_index', 'cn_soundarajan_hopcroft') | score: 0.8539674103298573
# train on col: ('preferential_attachment', 'adamic_adar_index', 'within_inter_cluster') | score: 0.8450393636403126
# train on col: ('preferential_attachment', 'adamic_adar_index', 'ra_index_soundarajan_hopcroft') | score: 0.8484429578562467
# train on col: ('preferential_attachment', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8533132660961643
# train on col: ('preferential_attachment', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8539801865844217
# train on col: ('preferential_attachment', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8173864382613051
# train on col: ('common_neighbors', 'jaccard_coef', 'resource_allocation_index') | score: 0.8527204478843801
# train on col: ('common_neighbors', 'jaccard_coef', 'adamic_adar_index') | score: 0.8540006285917245
# train on col: ('common_neighbors', 'jaccard_coef', 'cn_soundarajan_hopcroft') | score: 0.8515526982172015
# train on col: ('common_neighbors', 'jaccard_coef', 'within_inter_cluster') | score: 0.8634729437257092
# train on col: ('common_neighbors', 'jaccard_coef', 'ra_index_soundarajan_hopcroft') | score: 0.8526923401243385
# train on col: ('common_neighbors', 'resource_allocation_index', 'adamic_adar_index') | score: 0.8446254129924288
# train on col: ('common_neighbors', 'resource_allocation_index', 'cn_soundarajan_hopcroft') | score: 0.8403428124624698
# train on col: ('common_neighbors', 'resource_allocation_index', 'within_inter_cluster') | score: 0.8634729437257092
# train on col: ('common_neighbors', 'resource_allocation_index', 'ra_index_soundarajan_hopcroft') | score: 0.8405497877864117
# train on col: ('common_neighbors', 'adamic_adar_index', 'cn_soundarajan_hopcroft') | score: 0.8459158147034248
# train on col: ('common_neighbors', 'adamic_adar_index', 'within_inter_cluster') | score: 0.8634729437257092
# train on col: ('common_neighbors', 'adamic_adar_index', 'ra_index_soundarajan_hopcroft') | score: 0.8447633965417234
# train on col: ('common_neighbors', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8634729437257092
# train on col: ('common_neighbors', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8403606992188598
# train on col: ('common_neighbors', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8634729437257092
# train on col: ('jaccard_coef', 'resource_allocation_index', 'adamic_adar_index') | score: 0.8538856423006457
# train on col: ('jaccard_coef', 'resource_allocation_index', 'cn_soundarajan_hopcroft') | score: 0.8526718981170356
# train on col: ('jaccard_coef', 'resource_allocation_index', 'within_inter_cluster') | score: 0.8518797703340479
# train on col: ('jaccard_coef', 'resource_allocation_index', 'ra_index_soundarajan_hopcroft') | score: 0.8439814897623872
# train on col: ('jaccard_coef', 'adamic_adar_index', 'cn_soundarajan_hopcroft') | score: 0.8538933080533843
# train on col: ('jaccard_coef', 'adamic_adar_index', 'within_inter_cluster') | score: 0.8466593927190681
# train on col: ('jaccard_coef', 'adamic_adar_index', 'ra_index_soundarajan_hopcroft') | score: 0.8542484879302723
# train on col: ('jaccard_coef', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8509854325145457
# train on col: ('jaccard_coef', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8514530434315998
# train on col: ('jaccard_coef', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8333158724520955
# train on col: ('resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft') | score: 0.844584528977823
# train on col: ('resource_allocation_index', 'adamic_adar_index', 'within_inter_cluster') | score: 0.846156008289234
# train on col: ('resource_allocation_index', 'adamic_adar_index', 'ra_index_soundarajan_hopcroft') | score: 0.8451901234441715
# train on col: ('resource_allocation_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8395481294285693
# train on col: ('resource_allocation_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8404961275172416
# train on col: ('resource_allocation_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8328942560514729
# train on col: ('adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8463399863549601
# train on col: ('adamic_adar_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8447301782798562
# train on col: ('adamic_adar_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.846173895045624
# train on col: ('cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.856742412821227

# %%
test_x = test_df_data[list(best_col)]
y_pred = best_model.predict(test_x)
print(accuracy_score(y_pred, y_test))
# Out:
# 0.7295936009603778

# %% [markdown]
# ### With 5 cols

# %%
import itertools
cbn = list(itertools.combinations(col, 5))

# %%
train_y = train_df_data['connected'].values
best_score = 0.0
best_model = None
best_col = None
for col_train in cbn:
  train_x = train_df_data[list(col_train)].values
  model = LogisticRegression()
  model.fit(train_x, train_y)
  pred = model.predict(train_x)
  score = accuracy_score(pred, train_y)
  print(f'train on col: {col_train} | score: {score}')
  if score > best_score:
    best_score = score
    best_model = model
    best_col = col_train
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index') | score: 0.8490664390789854
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'cn_soundarajan_hopcroft') | score: 0.853768100758654
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'within_inter_cluster') | score: 0.8604143083830117
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'ra_index_soundarajan_hopcroft') | score: 0.8601741147972025
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'adamic_adar_index', 'cn_soundarajan_hopcroft') | score: 0.853768100758654
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'adamic_adar_index', 'within_inter_cluster') | score: 0.8603274298519743
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'adamic_adar_index', 'ra_index_soundarajan_hopcroft') | score: 0.8602558828264142
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8591239066720157
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8537706560095668
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8603938663757088
# train on col: ('preferential_attachment', 'common_neighbors', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft') | score: 0.8537604350059154
# train on col: ('preferential_attachment', 'common_neighbors', 'resource_allocation_index', 'adamic_adar_index', 'within_inter_cluster') | score: 0.8603223193501486
# train on col: ('preferential_attachment', 'common_neighbors', 'resource_allocation_index', 'adamic_adar_index', 'ra_index_soundarajan_hopcroft') | score: 0.8602661038300656
# train on col: ('preferential_attachment', 'common_neighbors', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8591443486793185
# train on col: ('preferential_attachment', 'common_neighbors', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.853768100758654
# train on col: ('preferential_attachment', 'common_neighbors', 'resource_allocation_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8604066426302731
# train on col: ('preferential_attachment', 'common_neighbors', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8599109239531776
# train on col: ('preferential_attachment', 'common_neighbors', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.853768100758654
# train on col: ('preferential_attachment', 'common_neighbors', 'adamic_adar_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8603197640992357
# train on col: ('preferential_attachment', 'common_neighbors', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8591239066720157
# train on col: ('preferential_attachment', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft') | score: 0.8539597445771188
# train on col: ('preferential_attachment', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'within_inter_cluster') | score: 0.849633704781641
# train on col: ('preferential_attachment', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'ra_index_soundarajan_hopcroft') | score: 0.8484097395943795
# train on col: ('preferential_attachment', 'jaccard_coef', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8532979345906871
# train on col: ('preferential_attachment', 'jaccard_coef', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8539878523371602
# train on col: ('preferential_attachment', 'jaccard_coef', 'resource_allocation_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8404169147389428
# train on col: ('preferential_attachment', 'jaccard_coef', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8547365408546292
# train on col: ('preferential_attachment', 'jaccard_coef', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8539597445771188
# train on col: ('preferential_attachment', 'jaccard_coef', 'adamic_adar_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8497308043163299
# train on col: ('preferential_attachment', 'jaccard_coef', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8533030450925129
# train on col: ('preferential_attachment', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8547927563747122
# train on col: ('preferential_attachment', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8539622998280316
# train on col: ('preferential_attachment', 'resource_allocation_index', 'adamic_adar_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8492171988828443
# train on col: ('preferential_attachment', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8533081555943386
# train on col: ('preferential_attachment', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8546931015891105
# train on col: ('common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft') | score: 0.8534154761326789
# train on col: ('common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'within_inter_cluster') | score: 0.8461611187910597
# train on col: ('common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'ra_index_soundarajan_hopcroft') | score: 0.8533260423507286
# train on col: ('common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8490511075735082
# train on col: ('common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8527230031352929
# train on col: ('common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8455044193064538
# train on col: ('common_neighbors', 'jaccard_coef', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8569391671415174
# train on col: ('common_neighbors', 'jaccard_coef', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8534768021545875
# train on col: ('common_neighbors', 'jaccard_coef', 'adamic_adar_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8463757598677402
# train on col: ('common_neighbors', 'jaccard_coef', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8486857066929687
# train on col: ('common_neighbors', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8467769342610597
# train on col: ('common_neighbors', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8445998604833002
# train on col: ('common_neighbors', 'resource_allocation_index', 'adamic_adar_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8448911590873666
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# train on col: ('common_neighbors', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8427243063132585
# train on col: ('common_neighbors', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8468944758030514
# train on col: ('jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8462454420711841
# train on col: ('jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8533618158635087
# train on col: ('jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8542791509412266
# train on col: ('jaccard_coef', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8443443353920138
# train on col: ('jaccard_coef', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8569391671415174
# train on col: ('resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.844771062294462

# %%
test_x = test_df_data[list(best_col)]
y_pred = best_model.predict(test_x)
print(accuracy_score(y_pred, y_test))
# Out:
# 0.7191286136501537

# %% [markdown]
# ### With 6 cols

# %%
import itertools
cbn = list(itertools.combinations(col, 6))

# %%
train_y = train_df_data['connected'].values
best_score = 0.0
best_model = None
best_col = None
for col_train in cbn:
  train_x = train_df_data[list(col_train)].values
  model = LogisticRegression()
  model.fit(train_x, train_y)
  pred = model.predict(train_x)
  score = accuracy_score(pred, train_y)
  print(f'train on col: {col_train} | score: {score}')
  if score > best_score:
    best_score = score
    best_model = model
    best_col = col_train
# Out:
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft') | score: 0.8537553245040896
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'within_inter_cluster') | score: 0.8603325403538
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'ra_index_soundarajan_hopcroft') | score: 0.8602558828264142
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8591443486793185
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.853768100758654
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8604040873793602
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8599058134513519
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8537629902568282
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'adamic_adar_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8603120983464971
# train on col: ('preferential_attachment', 'common_neighbors', 'jaccard_coef', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8591187961701899
# train on col: ('preferential_attachment', 'common_neighbors', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8599185897059162
# train on col: ('preferential_attachment', 'common_neighbors', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8537553245040896
# train on col: ('preferential_attachment', 'common_neighbors', 'resource_allocation_index', 'adamic_adar_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.847538399033093
# train on col: ('preferential_attachment', 'common_neighbors', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8591443486793185
# train on col: ('preferential_attachment', 'common_neighbors', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8599109239531776
# train on col: ('preferential_attachment', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8548464166438824
# train on col: ('preferential_attachment', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8474310784947527
# train on col: ('preferential_attachment', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.849373069188529
# train on col: ('preferential_attachment', 'jaccard_coef', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8533132660961643
# train on col: ('preferential_attachment', 'jaccard_coef', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8495749340106452
# train on col: ('preferential_attachment', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8548183088838408
# train on col: ('common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.8470120173450432
# train on col: ('common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8534946889109776
# train on col: ('common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8455401928192339
# train on col: ('common_neighbors', 'jaccard_coef', 'resource_allocation_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8478629158990267
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# train on col: ('common_neighbors', 'jaccard_coef', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8465418511770764
# train on col: ('common_neighbors', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8460819060127609
# train on col: ('jaccard_coef', 'resource_allocation_index', 'adamic_adar_index', 'cn_soundarajan_hopcroft', 'within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8569391671415174

# %%
test_x = test_df_data[list(best_col)]
y_pred = best_model.predict(test_x)
print(accuracy_score(y_pred, y_test))
# Out:
# 0.7191123028843959

# %% [markdown]
# ### With 2 cols

# %%
import itertools
cbn = list(itertools.combinations(col, 2))

# %%
train_y = train_df_data['connected'].values
best_score = 0.0
best_model = None
best_col = None
for col_train in cbn:
  train_x = train_df_data[list(col_train)].values
  model = LogisticRegression()
  model.fit(train_x, train_y)
  pred = model.predict(train_x)
  score = accuracy_score(pred, train_y)
  print(f'train on col: {col_train} | score: {score}')
  if score > best_score:
    best_score = score
    best_model = model
    best_col = col_train
# Out:
# train on col: ('preferential_attachment', 'common_neighbors') | score: 0.8602124435608954
# train on col: ('preferential_attachment', 'resource_allocation_index') | score: 0.5004791095461619
# train on col: ('preferential_attachment', 'adamic_adar_index') | score: 0.8486141596674085
# train on col: ('preferential_attachment', 'cn_soundarajan_hopcroft') | score: 0.8539827418353345
# train on col: ('preferential_attachment', 'within_inter_cluster') | score: 0.7931217755927543
# train on col: ('preferential_attachment', 'ra_index_soundarajan_hopcroft') | score: 0.5004791095461619
# train on col: ('common_neighbors', 'jaccard_coef') | score: 0.8516421319991516
# train on col: ('common_neighbors', 'resource_allocation_index') | score: 0.8405906718010175
# train on col: ('common_neighbors', 'adamic_adar_index') | score: 0.8460665745072837
# train on col: ('common_neighbors', 'cn_soundarajan_hopcroft') | score: 0.8634729437257092
# train on col: ('common_neighbors', 'within_inter_cluster') | score: 0.8634729437257092
# train on col: ('common_neighbors', 'ra_index_soundarajan_hopcroft') | score: 0.8400821768693577
# train on col: ('jaccard_coef', 'resource_allocation_index') | score: 0.8438665034713083
# train on col: ('jaccard_coef', 'adamic_adar_index') | score: 0.854366029472264
# train on col: ('jaccard_coef', 'cn_soundarajan_hopcroft') | score: 0.8508321174597739
# train on col: ('jaccard_coef', 'within_inter_cluster') | score: 0.8466440612135908
# train on col: ('jaccard_coef', 'ra_index_soundarajan_hopcroft') | score: 0.8417993054828019
# train on col: ('resource_allocation_index', 'adamic_adar_index') | score: 0.8451620156841301
# train on col: ('resource_allocation_index', 'cn_soundarajan_hopcroft') | score: 0.8396631157196481
# train on col: ('resource_allocation_index', 'within_inter_cluster') | score: 0.8353728494369504
# train on col: ('resource_allocation_index', 'ra_index_soundarajan_hopcroft') | score: 0.8157076384115538
# train on col: ('adamic_adar_index', 'cn_soundarajan_hopcroft') | score: 0.8460359114963294
# train on col: ('adamic_adar_index', 'within_inter_cluster') | score: 0.8463118785949186
# train on col: ('adamic_adar_index', 'ra_index_soundarajan_hopcroft') | score: 0.8455657453283625
# train on col: ('cn_soundarajan_hopcroft', 'within_inter_cluster') | score: 0.856742412821227
# train on col: ('cn_soundarajan_hopcroft', 'ra_index_soundarajan_hopcroft') | score: 0.8488415769986534
# train on col: ('within_inter_cluster', 'ra_index_soundarajan_hopcroft') | score: 0.8170440346389813

# %%
test_x = test_df_data[list(best_col)].values
y_pred = best_model.predict(test_x)
print(accuracy_score(y_pred, y_test))
# Out:
# 0.7295936009603778
